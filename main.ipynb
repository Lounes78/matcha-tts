# %% [markdown]
# **Matcha-TTS Pipeline**
#
# - Token IDs [50, 47, 102, ...]
#     ↓
# - Intersperse → [0, 50, 0, 47, 0, 102, ...]
#     ↓
# - PyTorch Tensor [1, seq_len]
#     ↓
# - Charger Matcha-TTS
#     ↓
# - Inférence (synthesise)
#     ↓
# - Mel Spectrogram [1, 80, time_frames]

# %%
from utils.utils import *
import phonemizer

# %%
import os
os.environ["PHONEMIZER_ESPEAK_LIBRARY"] = r"C:\Program Files\eSpeak NG\libespeak-ng.dll"

# %% [markdown]
# ### Text → Phonèmes

# %%
# text to phonems 
import os
os.environ["PHONEMIZER_ESPEAK_LIBRARY"] = r"C:\Program Files\eSpeak NG\libespeak-ng.dll"

backend = phonemizer.backend.EspeakBackend(
    language="en-us",   
    with_stress=True
)

# %%
text = "Hey I am arezki"
phonemes = backend.phonemize([text], strip=True)[0]
print(f"Text: {text}")
print(f"Phonemes: {phonemes}")
# Out:
# Text: Hey I am arezki
# Phonemes: hˈeɪ aɪɐm ˈæɹɛzki

# %%
id_token = phonemes_to_sequence(phonemes)
print(f"Token IDs: {id_token}")
# Out:
# Token IDs: [50, 156, 47, 102, 16, 43, 102, 70, 55, 16, 156, 72, 123, 86, 68, 53, 51]

# %% [markdown]
# ### Token IDs → [MATCHA] → Mel Spectrogram
